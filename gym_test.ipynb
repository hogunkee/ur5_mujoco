# %%
from IPython.display import HTML, display
from gym.wrappers import Monitor
import base64
import glob
import gym
import io

# %%
def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        display(HTML(data='''<video alt="test" autoplay 
            loop controls style="height: 400px;">
            <source src="data:video/mp4;base64,{0}" type="video/mp4" />
            </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Could not find video")

def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %%
from pyvirtualdisplay import Display

Display().start()

# %%
env_name = "MountainCarContinuous-v0"
env = gym.make(env_name)
# Out:
# /home/dobro/dobrovenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env = wrap_env(gym.make(env_name))
obs = env.reset()
total_reward = 0

for t in range(100):
    action = env.action_space.sample() # get random value
    obs, reward, done, info = env.step(action)

    # Render the environment to virtual display
    env.render(mode='rgb_array')

    total_reward += reward
    if done:
        break

env.close()
print('Total Reward : {:.2f}'.format(total_reward))
show_video()
# Out:
# Total Reward : -3.20
# <video alt="test" autoplay
#             loop controls style="height: 400px;">
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
